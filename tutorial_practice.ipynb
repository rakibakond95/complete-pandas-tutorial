# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"], index=["x","y","z"])

# %%
df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z']

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.size
# Out:
# 9

# %%
df.shape
# Out:
# (3, 3)

# %%
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.tail(2)
# Out:
#    A  B  C
# y  4  5  6
# z  7  8  9

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df["B"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of x    2
# y    5
# z    8
# Name: B, dtype: int64>

# %% [markdown]
# Loading Datasets

# %%
coffee=pd.read_csv('./warmup-data/coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results=pd.read_csv('./data/results.csv')

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
noc_regions=pd.read_csv('./data/noc_regions.csv')

# %%
olympics_data = pd.read_excel('./data/olympics-data.xlsx',sheet_name='results')

# %%
olympics_data.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
bios=pd.read_csv('./data/bios.csv')

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# #

# %% [markdown]
# Accessing Dataset

# %%
bios.to_csv
# Out:
# <bound method NDFrame.to_csv of         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
coffee=pd.read_csv('./warmup-data/coffee.csv')

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head(6)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25

# %%
coffee.tail(5)
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(3)
# Out:
#         Day Coffee Type  Units Sold
# 8    Friday    Espresso          45
# 3   Tuesday       Latte          20
# 6  Thursday    Espresso          40

# %%
coffee.loc[:3]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffee.loc[3:]
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[0:4,["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
coffee.iloc[0:5,[1,2]]
# Out:
#   Coffee Type  Units Sold
# 0    Espresso          25
# 1       Latte          15
# 2    Espresso          30
# 3       Latte          20
# 4    Espresso          35

# %%
coffee.index=coffee["Day"]

# %%
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
coffee=pd.read_csv('./warmup-data/coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[2:4,["Units Sold"]]=10

# %%
coffee.head(5)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          10
# 3    Tuesday       Latte          10
# 4  Wednesday    Espresso          10

# %%
coffee.at[2,"Units Sold"]
# Out:
# np.float64(34.166666666666664)

# %%
coffee.at[2,"Coffee Type"]
# Out:
# 'Espresso'

# %%
coffee.iat[3,2]
# Out:
# np.float64(34.166666666666664)

# %%
coffee.iat[3,1]
# Out:
# 'Latte'

# %%
coffee.iat[4,1]
# Out:
# 'Espresso'

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.sort_values(["Units Sold"], ascending=True)
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          10
# 2     Tuesday    Espresso          10
# 4   Wednesday    Espresso          10
# 1      Monday       Latte          15
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 11   Saturday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values(["Units Sold"], ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 4   Wednesday    Espresso          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row)
    print("Name of coffee type:" ,row["Coffee Type"])
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
# Name of coffee type: Espresso
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
# Name of coffee type: Latte
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           10
# Name: 2, dtype: object
# Name of coffee type: Espresso
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          10
# Name: 3, dtype: object
# Name of coffee type: Latte
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            10
# Name: 4, dtype: object
# Name of coffee type: Espresso
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
# Name of coffee type: Latte
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
# Name of coffee type: Espresso
# 7
# Day            Thursday
# ...

# %% [markdown]
# Filtering Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios["weight_kg"]<50]
# Out:
#         athlete_id                 name   born_date        born_city  \
# 338            339          Sonam Chuki  1963-04-07              NaN
# 532            534           Pat Conway  1944-01-16       Birmingham
# 537            539       Rachel Fenwick  1935-10-25              NaN
# 596            598         Chan Siu Yuk  1955-12-21              NaN
# 599            601      Wong-Lau So Han  1946-04-25              NaN
# ...            ...                  ...         ...              ...
# 142409      146016       Catarina Costa  1996-09-21          Coimbra
# 143650      147304     Jourdan Delacruz  1998-05-20           Dallas
# 144061      147727   Francisca Mardones  1989-03-24         Santiago
# 144193      147874        Eva Pinkelnig  1988-05-27          Bregenz
# 144753      148454  Ioulia Chtchetinina  1995-12-24  Nizhny Novgorod
#
#                   born_region born_country               NOC  height_cm  \
# ...

# %%
bios.loc[bios["height_cm"]>200, ["name", "height_cm"]]
# Out:
#                       name  height_cm
# 1080        Bozhil Lozanov      208.0
# 1673      Alexis Rubalcaba      204.0
# 2647         Milan Šrejber      203.0
# 2827    Nik'oloz Deriugini      206.0
# 2832         Elşad Qadaşev      205.0
# ...                    ...        ...
# 143784  Daniel Miklasevich      203.0
# 143833  Garrett Muagututia      205.0
# 143834         Kyle Ensing      201.0
# 143835         Mitch Stahl      203.0
# 143919   Emerson Rodríguez      204.0
#
# [1219 rows x 2 columns]

# %%
bios[bios["height_cm"]> 200][["name", "height_cm"]]
# Out:
#                       name  height_cm
# 1080        Bozhil Lozanov      208.0
# 1673      Alexis Rubalcaba      204.0
# 2647         Milan Šrejber      203.0
# 2827    Nik'oloz Deriugini      206.0
# 2832         Elşad Qadaşev      205.0
# ...                    ...        ...
# 143784  Daniel Miklasevich      203.0
# 143833  Garrett Muagututia      205.0
# 143834         Kyle Ensing      201.0
# 143835         Mitch Stahl      203.0
# 143919   Emerson Rodríguez      204.0
#
# [1219 rows x 2 columns]

# %%
bios[(bios['height_cm']<158) & (bios['born_country']=='USA')] [["name","height_cm"]]
# Out:
#                     name  height_cm
# 2208    Melanie Skillman      155.0
# 8577         Bill Bossio      155.0
# 8605      Frankie Genaro      156.0
# 8625      Maurice Frilot      150.0
# 8700           Ray Perez      155.0
# ...                  ...        ...
# 143538        Jade Carey      157.0
# 143539     Jordan Chiles      150.0
# 143540   MyKayla Skinner      152.0
# 143544    Sakura Kokumai      152.0
# 143650  Jourdan Delacruz      150.0
#
# [270 rows x 2 columns]

# %%
bios[bios['name'].str.contains('sam' ,case=False)]
# Out:
#         athlete_id                    name  born_date        born_city  \
# 33              34  Jean-Pierre Samazeuilh 1891-01-17         Bordeaux
# 68              69               Sam Smith 1971-11-27           Epping
# 690            693      Uladzimir Samsonau 1976-04-17            Minsk
# 1123          1130               Ek Sam An 1944-01-16              NaN
# 1223          1230           Samuel Rennie 1903-07-18         Montréal
# ...            ...                     ...        ...              ...
# 145121      148837       Aleksandr Samonov 1995-08-23  Moskva (Moscow)
# 145132      148848          Samir Mastiyev 1993-01-13    Yekaterinburg
# 145254      148974           Samuel Kňažko 2002-08-07          Trenčín
# 145260      148980            Samuel Takáč 1991-12-03           Poprad
# 145409      149132             Sam Hentges 1999-07-26     New Brighton
#
#        born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['name'].str.contains("altman",case=False)]
# Out:
#         athlete_id               name   born_date      born_city born_region  \
# 13285        13365  Virgilius Altmann  1913-02-09  Wien (Vienna)        Wien
# 116682      118090        Mike Altman  1975-08-21    Los Angeles  California
# 125005      127348      Mario Altmann  1986-11-04  Wien (Vienna)        Wien
# 126153      128503      Livia Altmann  1994-12-13     Glarus Süd      Glarus
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 13285           AUT        Austria        NaN        NaN  1943-10-17
# 116682          USA  United States      183.0       73.0         NaN
# 125005          AUT        Austria      193.0       98.0         NaN
# 126153          SUI    Switzerland      165.0       64.0         NaN

# %%
bios[bios['name'].str.contains('sam|patrick', case=False)]
# Out:
#         athlete_id                    name   born_date      born_city  \
# 6                7           Patrick Chila  1969-11-27    Ris-Orangis
# 33              34  Jean-Pierre Samazeuilh  1891-01-17       Bordeaux
# 68              69               Sam Smith  1971-11-27         Epping
# 119            120        Patrick Wheatley  1899-01-20        Vryheid
# 319            320       Patrick De Koning  1961-04-23    Dendermonde
# ...            ...                     ...         ...            ...
# 145132      148848          Samir Mastiyev  1993-01-13  Yekaterinburg
# 145254      148974           Samuel Kňažko  2002-08-07        Trenčín
# 145260      148980            Samuel Takáč  1991-12-03         Poprad
# 145409      149132             Sam Hentges  1999-07-26   New Brighton
# 145435      149158       Patrick Gasienica  1998-11-28        McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['born_country'].isin(["USA","RSA","GBR"]) & (bios['name'].str.startswith("patrick"))]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios[bios['born_country'].isin(['USA',"GBR"]) & (bios['name'].str.startswith('Patrick'))]
# Out:
#         athlete_id                             name  born_date  \
# 18585        18712                   Patrick Austen 1933-03-18
# 32759        33005                  Patrick O'Neill 1956-03-20
# 34513        34782                   Patrick Harvey 1935-11-28
# 35830        36114                Patrick Croskerry 1942-10-07
# 36989        37284                Patrick Delafield 1946-04-14
# 37188        37484                  Patrick Sweeney 1952-08-12
# 37223        37519                   Patrick Wright 1945-05-20
# 51061        51420                  Patrick Jeffrey 1965-06-24
# 62910        63378                      Patrick Pym 1936-09-06
# 86494        87184                   Patrick Howdle 1963-04-24
# 98204        98997                Patrick Winterton 1961-09-15
# 98696        99492  Patrick-Paul Schwarzacher-Joyce 1972-07-05
# 117509      119009                   Patrick Deneen 1987-12-25
# 117801      119335                     Patrick Kane 1988-11-19
# ...

# %%
bios.query('born_country=="USA" and born_city=="Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %% [markdown]
# Add a new column

# %%
coffee['price']=5

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25      5
# 1      Monday       Latte          15      5
# 2     Tuesday    Espresso          10      5
# 3     Tuesday       Latte          10      5
# 4   Wednesday    Espresso          10      5
# 5   Wednesday       Latte          25      5
# 6    Thursday    Espresso          40      5
# 7    Thursday       Latte          30      5
# 8      Friday    Espresso          45      5
# 9      Friday       Latte          35      5
# 10   Saturday    Espresso          45      5
# 11   Saturday       Latte          35      5
# 12     Sunday    Espresso          45      5
# 13     Sunday       Latte          35      5

# %%
import numpy as np
coffee['new_price']=np.where(coffee['Coffee Type']=='Espresso',4,5)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25      5          4
# 1      Monday       Latte          15      5          5
# 2     Tuesday    Espresso          10      5          4
# 3     Tuesday       Latte          10      5          5
# 4   Wednesday    Espresso          10      5          4
# 5   Wednesday       Latte          25      5          5
# 6    Thursday    Espresso          40      5          4
# 7    Thursday       Latte          30      5          5
# 8      Friday    Espresso          45      5          4
# 9      Friday       Latte          35      5          5
# 10   Saturday    Espresso          45      5          4
# 11   Saturday       Latte          35      5          5
# 12     Sunday    Espresso          45      5          4
# 13     Sunday       Latte          35      5          5

# %%
coffee.drop(columns=['price'], inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25          4
# 1      Monday       Latte          15          5
# 2     Tuesday    Espresso          10          4
# 3     Tuesday       Latte          10          5
# 4   Wednesday    Espresso          10          4
# 5   Wednesday       Latte          25          5
# 6    Thursday    Espresso          40          4
# 7    Thursday       Latte          30          5
# 8      Friday    Espresso          45          4
# 9      Friday       Latte          35          5
# 10   Saturday    Espresso          45          4
# 11   Saturday       Latte          35          5
# 12     Sunday    Espresso          45          4
# 13     Sunday       Latte          35          5

# %%
coffee.rename(columns={'new_price':'price'}, inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25      4
# 1      Monday       Latte          15      5
# 2     Tuesday    Espresso          10      4
# 3     Tuesday       Latte          10      5
# 4   Wednesday    Espresso          10      4
# 5   Wednesday       Latte          25      5
# 6    Thursday    Espresso          40      4
# 7    Thursday       Latte          30      5
# 8      Friday    Espresso          45      4
# 9      Friday       Latte          35      5
# 10   Saturday    Espresso          45      4
# 11   Saturday       Latte          35      5
# 12     Sunday    Espresso          45      4
# 13     Sunday       Latte          35      5

# %%
coffee['revenue']= coffee['Units Sold']*coffee['price']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25      4      100
# 1      Monday       Latte          15      5       75
# 2     Tuesday    Espresso          10      4       40
# 3     Tuesday       Latte          10      5       50
# 4   Wednesday    Espresso          10      4       40
# 5   Wednesday       Latte          25      5      125
# 6    Thursday    Espresso          40      4      160
# 7    Thursday       Latte          30      5      150
# 8      Friday    Espresso          45      4      180
# 9      Friday       Latte          35      5      175
# 10   Saturday    Espresso          45      4      180
# 11   Saturday       Latte          35      5      175
# 12     Sunday    Espresso          45      4      180
# 13     Sunday       Latte          35      5      175

# %%
bios_new= bios.copy()

# %%
bios_new['first_name']=bios_new['name'].str.split(' ').str[0]

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
bios_new.query('first_name=="Patrick"')
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# 2454          2465  Patrick Birocheau  1955-09-23                 Béjaïa
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios_new['born_datetime']=pd.to_datetime(bios_new['born_date'])

# %%
bios_new['born_year']=bios_new['born_datetime'].dt.year

# %%
bios_new[['name','born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new.to_csv('./data/bios_new.csv', index= False)

# %%
bios['height_category']=bios['height_cm'].apply(lambda x: 'short' if x < 165 else('average' if x < 185 else 'tall'))

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            tall
# 1         NaN         average
# 2  1994-07-17         average
# 3  1978-03-20         average
# 4  1930-07-25            tall

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] <70 :
        return'Lightweight'
    elif row['height_cm']< 185 and row['weight_kg'] <=80:
        return 'Middleweight'
    else:
        return 'Heavyweight'

bios['category'] = bios.apply(categorize_athlete, axis=1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category
# 0  1960-10-02            tall   Heavyweight
# 1         NaN         average  Middleweight
# 2  1994-07-17         average  Middleweight
# ...

# %%
bios.head(39)
# Out:
#     athlete_id                      name   born_date          born_city  \
# 0            1     Jean-François Blanchy  1886-12-12           Bordeaux
# 1            2            Arnaud Boetsch  1969-04-01             Meulan
# 2            3              Jean Borotra  1898-08-13           Biarritz
# 3            4           Jacques Brugnon  1895-05-11        Paris VIIIe
# 4            5              Albert Canet  1878-04-17         Wandsworth
# 5            6         Nicolas Chatelain  1970-01-13             Amiens
# 6            7             Patrick Chila  1969-11-27        Ris-Orangis
# 7            8              Henri Cochet  1901-12-14       Villeurbanne
# 8            9             Marcel Cousin  1896-08-04              Nîmes
# 9           10        Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 10          11   Élie, Comte de Lastours  1874-08-12            Orgeval
# 11          12               Max Decugis  1882-09-24         Paris XVIe
# ...

# %%
noc_regions.head(16)
# Out:
#     NOC          region                 notes
# 0   AFG     Afghanistan                   NaN
# 1   AHO         Curacao  Netherlands Antilles
# 2   ALB         Albania                   NaN
# 3   ALG         Algeria                   NaN
# 4   AND         Andorra                   NaN
# 5   ANG          Angola                   NaN
# 6   ANT         Antigua   Antigua and Barbuda
# 7   ANZ       Australia           Australasia
# 8   ARG       Argentina                   NaN
# 9   ARM         Armenia                   NaN
# 10  ARU           Aruba                   NaN
# 11  ASA  American Samoa                   NaN
# 12  AUS       Australia                   NaN
# 13  AUT         Austria                   NaN
# 14  AZE      Azerbaijan                   NaN
# 15  BAH         Bahamas                   NaN

# %%
noc_regions['notes'].isnull().sum()
# Out:
# np.int64(209)

# %%
noc_regions.fillna('NO notes')
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan              NO notes
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania              NO notes
# 3    ALG      Algeria              NO notes
# 4    AND      Andorra              NO notes
# ..   ...          ...                   ...
# 225  YEM        Yemen              NO notes
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia              NO notes
# 229  ZIM     Zimbabwe              NO notes
#
# [230 rows x 3 columns]

# %%
nocs=pd.read_csv('./data/noc_regions.csv')
bios_new=pd.merge(bios, nocs, left_on='born_country', right_on='NOC',how='left')

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# ...

# %%
usa= bios[bios['born_country']=='USA'].copy()
gbr= bios[bios['born_country']=='GBR'].copy()

# %%
new_df=pd.concat([usa,gbr])

# %%
new_df.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_category      category
# 54           average  Middleweight
# ...

# %%
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        height_category     category
# ...

# %%
coffee.loc[[2,3],'Units Sold'] = np.nan

# %%
coffee= pd.read_csv('./warmup-data/coffee.csv')

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[[2,3],'Units Sold'] =np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price     revenue  yesterday_revenue  \
# 0      Monday    Espresso        25.0      5  125.000000                NaN
# 1      Monday       Latte        15.0      6   90.000000                NaN
# 2     Tuesday    Espresso         NaN      5  170.833333         125.000000
# 3     Tuesday       Latte         NaN      6  205.000000          90.000000
# 4   Wednesday    Espresso        35.0      5  175.000000         170.833333
# 5   Wednesday       Latte        25.0      6  150.000000         205.000000
# 6    Thursday    Espresso        40.0      5  200.000000         175.000000
# 7    Thursday       Latte        30.0      6  180.000000         150.000000
# 8      Friday    Espresso        45.0      5  225.000000         200.000000
# 9      Friday       Latte        35.0      6  210.000000         180.000000
# 10   Saturday    Espresso        45.0      5  225.000000         225.000000
# ...

# %%
coffee.dropna(subset=['Units Sold'])
# Out:
#           Day Coffee Type  Units Sold  Price  revenue  yesterday_revenue  \
# 0      Monday    Espresso        25.0      5    125.0                NaN
# 1      Monday       Latte        15.0      6     90.0                NaN
# 4   Wednesday    Espresso        35.0      5    175.0         170.833333
# 5   Wednesday       Latte        25.0      6    150.0         205.000000
# 6    Thursday    Espresso        40.0      5    200.0         175.000000
# 7    Thursday       Latte        30.0      6    180.0         150.000000
# 8      Friday    Espresso        45.0      5    225.0         200.000000
# 9      Friday       Latte        35.0      6    210.0         180.000000
# 10   Saturday    Espresso        45.0      5    225.0         225.000000
# 11   Saturday       Latte        35.0      6    210.0         210.000000
# 12     Sunday    Espresso        45.0      5    225.0         225.000000
# 13     Sunday       Latte        35.0      6    210.0         210.000000
#
#     pct_change
# ...

# %%
coffee['Units Sold'].fillna(coffee['Units Sold'].mean(), inplace= True)
# Out:
# C:\Users\rakib\AppData\Local\Temp\ipykernel_18416\1163417235.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   coffee['Units Sold'].fillna(coffee['Units Sold'].mean(), inplace= True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price     revenue  yesterday_revenue  \
# 0      Monday    Espresso        25.0      5  125.000000                NaN
# 1      Monday       Latte        15.0      6   90.000000                NaN
# 2     Tuesday    Espresso         NaN      5  170.833333         125.000000
# 3     Tuesday       Latte         NaN      6  205.000000          90.000000
# 4   Wednesday    Espresso        35.0      5  175.000000         170.833333
# 5   Wednesday       Latte        25.0      6  150.000000         205.000000
# 6    Thursday    Espresso        40.0      5  200.000000         175.000000
# 7    Thursday       Latte        30.0      6  180.000000         150.000000
# 8      Friday    Espresso        45.0      5  225.000000         200.000000
# 9      Friday       Latte        35.0      6  210.000000         180.000000
# 10   Saturday    Espresso        45.0      5  225.000000         225.000000
# ...

# %%
coffee['Price']=np.where(coffee['Coffee Type']=='Espresso',5,6)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso   25.000000      5
# 1      Monday       Latte   15.000000      6
# 2     Tuesday    Espresso   34.166667      5
# 3     Tuesday       Latte   34.166667      6
# 4   Wednesday    Espresso   35.000000      5
# 5   Wednesday       Latte   25.000000      6
# 6    Thursday    Espresso   40.000000      5
# 7    Thursday       Latte   30.000000      6
# 8      Friday    Espresso   45.000000      5
# 9      Friday       Latte   35.000000      6
# 10   Saturday    Espresso   45.000000      5
# 11   Saturday       Latte   35.000000      6
# 12     Sunday    Espresso   45.000000      5
# 13     Sunday       Latte   35.000000      6

# %%
coffee.dropna(subset=['Units Sold'])
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso   25.000000      5
# 1      Monday       Latte   15.000000      6
# 2     Tuesday    Espresso   34.166667      5
# 3     Tuesday       Latte   34.166667      6
# 4   Wednesday    Espresso   35.000000      5
# 5   Wednesday       Latte   25.000000      6
# 6    Thursday    Espresso   40.000000      5
# 7    Thursday       Latte   30.000000      6
# 8      Friday    Espresso   45.000000      5
# 9      Friday       Latte   35.000000      6
# 10   Saturday    Espresso   45.000000      5
# 11   Saturday       Latte   35.000000      6
# 12     Sunday    Espresso   45.000000      5
# 13     Sunday       Latte   35.000000      6

# %%
bios['name'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\rakib\AppData\Local\Temp\ipykernel_18416\1913398038.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   bios['name'].fillna('Unknown',inplace=True)

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  Price  revenue  yesterday_revenue  \
# 0      Monday    Espresso        25.0      5    125.0                NaN
# 1      Monday       Latte        15.0      6     90.0                NaN
# 4   Wednesday    Espresso        35.0      5    175.0         170.833333
# 5   Wednesday       Latte        25.0      6    150.0         205.000000
# 6    Thursday    Espresso        40.0      5    200.0         175.000000
# 7    Thursday       Latte        30.0      6    180.0         150.000000
# 8      Friday    Espresso        45.0      5    225.0         200.000000
# 9      Friday       Latte        35.0      6    210.0         180.000000
# 10   Saturday    Espresso        45.0      5    225.0         225.000000
# 11   Saturday       Latte        35.0      6    210.0         210.000000
# 12     Sunday    Espresso        45.0      5    225.0         225.000000
# 13     Sunday       Latte        35.0      6    210.0         210.000000
#
#     pct_change
# ...

# %% [markdown]
# Aggregating Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category
# 0  1960-10-02            tall   Heavyweight
# 1         NaN         average  Middleweight
# 2  1994-07-17         average  Middleweight
# ...

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest            1378
# Moskva (Moscow)      883
# Oslo                 708
# Stockholm            629
# Praha (Prague)       600
#                     ...
# Roth                   1
# Romoos                 1
# Dva Polya Artash       1
# Dulwich Hill           1
# Visé                   1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Massachusetts            530
# Pennsylvania             530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
bios[bios['born_country']=='USA']['born_city'].value_counts().tail(19)
# Out:
# born_city
# Milpitas          1
# Chesterfield      1
# American Fork     1
# Bowlegs           1
# Apopka            1
# Huntersville      1
# Monroeville       1
# Sugar Land        1
# Pembroke Pines    1
# Conyers           1
# Richardson        1
# Duanesburg        1
# Southlake         1
# Salina            1
# Tualatin          1
# Old Saybrook      1
# Haleiwa           1
# Allen Park        1
# Lakeville         1
# Name: count, dtype: int64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    269.166667
# Latte       209.166667
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    38.452381
# Latte       29.880952
# Name: Units Sold, dtype: float64

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso   25.000000      5
# 1      Monday       Latte   15.000000      6
# 2     Tuesday    Espresso   34.166667      5
# 3     Tuesday       Latte   34.166667      6
# 4   Wednesday    Espresso   35.000000      5
# 5   Wednesday       Latte   25.000000      6
# 6    Thursday    Espresso   40.000000      5
# 7    Thursday       Latte   30.000000      6
# 8      Friday    Espresso   45.000000      5
# 9      Friday       Latte   35.000000      6
# 10   Saturday    Espresso   45.000000      5
# 11   Saturday       Latte   35.000000      6
# 12     Sunday    Espresso   45.000000      5
# 13     Sunday       Latte   35.000000      6

# %%
coffee.groupby(['Coffee Type', 'Day']).agg({'Units Sold':'sum', 'Price':'mean'})
# Out:
#                        Units Sold  Price
# Coffee Type Day
# Espresso    Friday      45.000000    5.0
#             Monday      25.000000    5.0
#             Saturday    45.000000    5.0
#             Sunday      45.000000    5.0
#             Thursday    40.000000    5.0
#             Tuesday     34.166667    5.0
#             Wednesday   35.000000    5.0
# Latte       Friday      35.000000    6.0
#             Monday      15.000000    6.0
#             Saturday    35.000000    6.0
#             Sunday      35.000000    6.0
#             Thursday    30.000000    6.0
#             Tuesday     34.166667    6.0
#             Wednesday   25.000000    6.0

# %%
coffee['revenue']= coffee['Price']* coffee['Units Sold']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price     revenue
# 0      Monday    Espresso   25.000000      5  125.000000
# 1      Monday       Latte   15.000000      6   90.000000
# 2     Tuesday    Espresso   34.166667      5  170.833333
# 3     Tuesday       Latte   34.166667      6  205.000000
# 4   Wednesday    Espresso   35.000000      5  175.000000
# 5   Wednesday       Latte   25.000000      6  150.000000
# 6    Thursday    Espresso   40.000000      5  200.000000
# 7    Thursday       Latte   30.000000      6  180.000000
# 8      Friday    Espresso   45.000000      5  225.000000
# 9      Friday       Latte   35.000000      6  210.000000
# 10   Saturday    Espresso   45.000000      5  225.000000
# 11   Saturday       Latte   35.000000      6  210.000000
# 12     Sunday    Espresso   45.000000      5  225.000000
# 13     Sunday       Latte   35.000000      6  210.000000

# %%
pivot = coffee.pivot (columns= 'Coffee Type', index= 'Day', values='revenue')

# %%
print(pivot)
# Out:
# Coffee Type    Espresso  Latte
# Day
# Friday       225.000000  210.0
# Monday       125.000000   90.0
# Saturday     225.000000  210.0
# Sunday       225.000000  210.0
# Thursday     200.000000  180.0
# Tuesday      170.833333  205.0
# Wednesday    175.000000  150.0

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso    1345.833333
# Latte       1255.000000
# dtype: float64

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       435.000000
# Monday       215.000000
# Saturday     435.000000
# Sunday       435.000000
# Thursday     380.000000
# Tuesday      375.833333
# Wednesday    325.000000
# dtype: float64

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])
bios['born_year'] =bios['born_date'].dt.year
bios['born_month'] = bios['born_date'].dt.month
bios.groupby([bios['born_year'], bios['born_month']])['name'].count().reset_index().sort_values('name',ascending=False)
# Out:
#       born_year  born_month  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1629     1986.0         1.0   227
# 1497     1975.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 51       1852.0         5.0     1
# 52       1852.0         6.0     1
# 1882     2008.0         7.0     1
# 1883     2008.0         8.0     1
# 1884     2009.0         1.0     1
#
# [1885 rows x 3 columns]

# %%
bios.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category  born_year  born_month
# 0  1960-10-02            tall   Heavyweight     1886.0        12.0
# ...

# %% [markdown]
# Advanced functionality-----shift() rank() cumsum() rolling()

# %%
coffee['yesterday_revenue'] = coffee['revenue'].shift(2)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price     revenue  yesterday_revenue
# 0      Monday    Espresso   25.000000      5  125.000000                NaN
# 1      Monday       Latte   15.000000      6   90.000000                NaN
# 2     Tuesday    Espresso   34.166667      5  170.833333         125.000000
# 3     Tuesday       Latte   34.166667      6  205.000000          90.000000
# 4   Wednesday    Espresso   35.000000      5  175.000000         170.833333
# 5   Wednesday       Latte   25.000000      6  150.000000         205.000000
# 6    Thursday    Espresso   40.000000      5  200.000000         175.000000
# 7    Thursday       Latte   30.000000      6  180.000000         150.000000
# 8      Friday    Espresso   45.000000      5  225.000000         200.000000
# 9      Friday       Latte   35.000000      6  210.000000         180.000000
# 10   Saturday    Espresso   45.000000      5  225.000000         225.000000
# ...

# %%
coffee['pct_change'] = coffee['revenue'] / coffee['yesterday_revenue']*100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price     revenue  yesterday_revenue  \
# 0      Monday    Espresso   25.000000      5  125.000000                NaN
# 1      Monday       Latte   15.000000      6   90.000000                NaN
# 2     Tuesday    Espresso   34.166667      5  170.833333         125.000000
# 3     Tuesday       Latte   34.166667      6  205.000000          90.000000
# 4   Wednesday    Espresso   35.000000      5  175.000000         170.833333
# 5   Wednesday       Latte   25.000000      6  150.000000         205.000000
# 6    Thursday    Espresso   40.000000      5  200.000000         175.000000
# 7    Thursday       Latte   30.000000      6  180.000000         150.000000
# 8      Friday    Espresso   45.000000      5  225.000000         200.000000
# 9      Friday       Latte   35.000000      6  210.000000         180.000000
# 10   Saturday    Espresso   45.000000      5  225.000000         225.000000
# ...

# %%
bios['height_rank']  = bios['height_cm'].rank(ascending=False)

# %%
bios[['name','height_cm','height_rank','born_country']].sort_values('height_rank')
# Out:
#                          name  height_cm  height_rank born_country
# 89070                Yao Ming      226.0          1.0          CHN
# 6978          Arvydas Sabonis      223.0          2.5          LTU
# 5781           Tommy Burleson      223.0          2.5          USA
# 5673           Gunther Behnke      221.0          5.0          GER
# 89075          Roberto Dueñas      221.0          5.0          ESP
# ...                       ...        ...          ...          ...
# 145490            Sin Ye-Chan        NaN          NaN          NaN
# 145491          Matthew Wepke        NaN          NaN          NaN
# 145492  Carlos García-Ordóñez        NaN          NaN          CUB
# 145493     Landysh Falyakhova        NaN          NaN          RUS
# 145499          Bill Phillips        NaN          NaN          AUS
#
# [145500 rows x 4 columns]

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios[(bios['born_city'].str.lower() == 'california') | (bios['born_region'].str.lower() == 'san francisco')]
# Out:
#         athlete_id               name  born_date   born_city   born_region  \
# 78008        78599       Frank Jarvis 1878-08-31  California  Pennsylvania
# 119901      121743  Andrew Rutherfurd 1988-12-21  California  Pennsylvania
#
#        born_country            NOC  height_cm  weight_kg   died_date  \
# 78008           USA  United States      167.0       58.0  1933-06-02
# 119901          USA        Bolivia      178.0       80.0         NaN
#
#        height_category      category  born_year  born_month  height_rank
# 78008          average   Lightweight     1878.0         8.0      87188.5
# 119901         average  Middleweight     1988.0        12.0      46966.0
